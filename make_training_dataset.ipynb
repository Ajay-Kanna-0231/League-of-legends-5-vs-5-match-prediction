# %%
import pickle
with open('list_of_matches.pkl', 'rb') as file:
    match_ids = pickle.load(file)
print(len(match_ids), match_ids)
# Out:
# 1763 ['NA1_5020516914', 'NA1_5020407113', 'NA1_5020373724', 'NA1_5020343197', 'NA1_5020323876', 'NA1_5020310796', 'NA1_5020292476', 'NA1_5019827562', 'NA1_5019626406', 'NA1_5019217363', 'NA1_5019180330', 'NA1_5018959316', 'NA1_5018709260', 'NA1_5018682815', 'NA1_5018649918', 'NA1_5018606049', 'NA1_5018437128', 'NA1_5018402732', 'NA1_5018282975', 'NA1_5017945522', 'NA1_5017632580', 'NA1_5017615728', 'NA1_5017598353', 'NA1_5017587594', 'NA1_5017293789', 'NA1_5017192856', 'NA1_5017152911', 'NA1_5016959471', 'NA1_5013830447', 'NA1_5013731483', 'NA1_5013633945', 'NA1_5013524926', 'NA1_5013506943', 'NA1_5013477585', 'NA1_5013461214', 'NA1_5012915234', 'NA1_5012851645', 'NA1_5012809583', 'NA1_5012796260', 'NA1_5012321671', 'NA1_5012303743', 'NA1_5012147763', 'NA1_5012128910', 'NA1_5012105596', 'NA1_5012092396', 'NA1_5011891064', 'NA1_5011524652', 'NA1_5011433003', 'NA1_5011402713', 'NA1_5011376884', 'NA1_5011351253', 'NA1_5011097104', 'NA1_5010987494', 'NA1_5010867546', 'NA1_5010843357', 'NA1_5010806464', 'NA1_5010635151', 'NA1_5010607403', 'NA1_5010588828', 'NA1_5009859422', 'NA1_5009545427', 'NA1_5009471687', 'NA1_5009399102', 'NA1_5009351483', 'NA1_5009241432', 'NA1_5009236005', 'NA1_5009067009', 'NA1_5009049330', 'NA1_5009027444', 'NA1_5009008092', 'NA1_5008980127', 'NA1_5008956949', 'NA1_5008924058', 'NA1_5008883625', 'NA1_5008859031', 'NA1_5008661512', 'NA1_5008650801', 'NA1_5008629779', 'NA1_5008596193', 'NA1_5008580108', 'NA1_5008407099', 'NA1_5008388426', 'NA1_5008374760', 'NA1_5008352201', 'NA1_5008330140', 'NA1_5008311926', 'NA1_5008277678', 'NA1_5008249308', 'NA1_5008217844', 'NA1_5008170990', 'NA1_5008104675', 'NA1_5008086575', 'NA1_5008049396', 'NA1_5008029191', 'NA1_5008009856', 'NA1_5007977438', 'NA1_5007949179', 'NA1_5007928450', 'NA1_5007917181', 'NA1_5007888731', 'NA1_5007681340', 'NA1_5007657909', 'NA1_5007625554', 'NA1_5007602789', 'NA1_5007566079', 'NA1_5007537562', 'NA1_5007489593', 'NA1_5007449195', 'NA1_5007424927', 'NA1_5007389688', 'NA1_5007363235', 'NA1_5007339113', 'NA1_5007319131', 'NA1_5007296789', 'NA1_5007246886', 'NA1_5007220946', 'NA1_5006364079', 'NA1_5006340439', 'NA1_5006323636', 'NA1_5005970660', 'NA1_5005908324', 'NA1_5005888121', 'NA1_5005834826', 'NA1_5005634119', 'NA1_5005616326', 'NA1_5005597990', 'NA1_5005328379', 'NA1_5005294460', 'NA1_5005249915', 'NA1_5005211261', 'NA1_5005177546', 'NA1_5005149159', 'NA1_5004975344', 'NA1_5004950001', 'NA1_5004924879', 'NA1_5004908915', 'NA1_5004597686', 'NA1_5004575684', 'NA1_5004545097', 'NA1_5004521283', 'NA1_5004443360', 'NA1_5004403890', 'NA1_5004366379', 'NA1_5003890237', 'NA1_5003861322', 'NA1_5003641660', 'NA1_5003625754', 'NA1_5003602590', 'NA1_5003563400', 'NA1_5003536311', 'NA1_5003379841', 'NA1_5003363277', 'NA1_5003331671', 'NA1_5003317997', 'NA1_5003214682', 'NA1_5003024422', 'NA1_5002884393', 'NA1_5002863603', 'NA1_5002595597', 'NA1_5002577742', 'NA1_5002286710', 'NA1_5002265260', 'NA1_5002113146', 'NA1_5002100002', 'NA1_5000830146', 'NA1_5000797659', 'NA1_5000777107', 'NA1_5000754646', 'NA1_5000500564', 'NA1_5000298361', 'NA1_5000126982', 'NA1_4999953237', 'NA1_4999929755', 'NA1_4999818882', 'NA1_4999802840', 'NA1_4999771723', 'NA1_4999756494', 'NA1_4999743461', 'NA1_4999464490', 'NA1_4999428828', 'NA1_4999401882', 'NA1_4999228811', 'NA1_4998997983', 'NA1_4998859447', 'NA1_4998803975', 'NA1_4998781474', 'NA1_4998774751', 'NA1_4998728609', 'NA1_4998703560', 'NA1_4998676538', 'NA1_4998643514', 'NA1_4998620738', 'NA1_4998415597', 'NA1_4998395421', 'NA1_4998370832', 'NA1_4998341584', 'NA1_4998320614', 'NA1_4998303249', 'NA1_4998270326', 'NA1_4998253689', 'NA1_4997159300', 'NA1_4997119797', 'NA1_4997082320', 'NA1_4996953701', 'NA1_4996691789', 'NA1_4996252246', 'NA1_4996222324', 'NA1_4995999357', 'NA1_4995970791', 'NA1_4995927713', 'NA1_4995752913', 'NA1_4995057267', 'NA1_4993919564', 'NA1_4993886770', 'NA1_4993855043', 'NA1_4993840314', 'NA1_4993772818', 'NA1_4993160791', 'NA1_4992791943', 'NA1_4992515715', 'NA1_4992472796', 'NA1_4992426372' ...

# %%
matches_data = []

# %%
import requests

def get_champion_data(api_key):
    url = f"https://ddragon.leagueoflegends.com/cdn/12.8.1/data/en_US/champion.json"
    response = requests.get(url)
    return response.json()

# Example usage
api_key = 'RGAPI-73de7a1d-bd48-401f-9ea2-12e33bd637f2'  # Replace with your valid API key
champion_data = get_champion_data(api_key)

# Create a dictionary mapping champion IDs to their names and classes
champion_classes = {
    "Tank": [],
    "Mage": [],
    "Assassin": [],
    "Marksman": [],
    "Support": [],
    "Fighter": []
}

for champ in champion_data['data'].values():
    # Assume champ['tags'] contains the class information
    for role in champ['tags']:
        if role in champion_classes:
            champion_classes[role].append(champ['name'])

print(champion_classes)
print(champion_classes.keys())
# Out:
# {'Tank': ['Aatrox', 'Alistar', 'Amumu', 'Blitzcrank', 'Braum', 'Camille', "Cho'Gath", 'Darius', 'Dr. Mundo', 'Galio', 'Garen', 'Gnar', 'Hecarim', 'Illaoi', 'Jarvan IV', 'Kled', 'Leona', 'Malphite', 'Maokai', 'Wukong', 'Nasus', 'Nautilus', 'Nunu & Willump', 'Olaf', 'Ornn', 'Poppy', 'Rammus', 'Rell', 'Renekton', 'Sejuani', 'Sett', 'Shen', 'Shyvana', 'Singed', 'Sion', 'Skarner', 'Tahm Kench', 'Trundle', 'Udyr', 'Urgot', 'Volibear', 'Warwick', 'Yorick', 'Zac'], 'Mage': ['Ahri', 'Amumu', 'Anivia', 'Annie', 'Aurelion Sol', 'Azir', 'Bard', 'Brand', 'Cassiopeia', "Cho'Gath", 'Diana', 'Elise', 'Evelynn', 'Ezreal', 'Fiddlesticks', 'Galio', 'Gragas', 'Heimerdinger', 'Ivern', 'Janna', 'Jhin', 'Karma', 'Karthus', 'Kassadin', 'Katarina', 'Kennen', "Kog'Maw", 'LeBlanc', 'Lillia', 'Lissandra', 'Lulu', 'Lux', 'Malzahar', 'Maokai', 'Morgana', 'Nami', 'Neeko', 'Nidalee', 'Orianna', 'Renata Glasc', 'Rumble', 'Ryze', 'Seraphine', 'Sona', 'Soraka', 'Swain', 'Sylas', 'Syndra', 'Taliyah', 'Twisted Fate', 'Varus', 'Veigar', "Vel'Koz", 'Vex', 'Viktor', 'Vladimir', 'Xerath', 'Yuumi', 'Ziggs', 'Zilean', 'Zoe', 'Zyra'], 'Assassin': ['Ahri', 'Akali', 'Akshan', 'Ekko', 'Evelynn', 'Fiora', 'Fizz', 'Gwen', 'Irelia', 'Jax', 'Kassadin', 'Katarina', 'Kayn', "Kha'Zix", 'LeBlanc', 'Lee Sin', 'Malzahar', 'Master Yi', 'Nidalee', 'Nocturne', 'Pantheon', 'Pyke', 'Qiyana', 'Quinn', 'Rengar', 'Riven', 'Shaco', 'Sylas', 'Talon', 'Teemo', 'Tristana', 'Tryndamere', 'Twitch', 'Vayne', 'Vi', 'Viego', 'Xin Zhao', 'Yasuo', 'Yone', 'Zed'], 'Marksman': ['Akshan', 'Aphelios', 'Ashe', 'Azir', 'Caitlyn', 'Corki', 'Draven', 'Ezreal', 'Graves', 'Jayce', 'Jhin', 'Jinx', "Kai'Sa", 'Kalista', 'Kennen', 'Kindred', "Kog'Maw", 'Lucian', 'Miss Fortune', 'Quinn', 'Samira', 'Senna', 'Sivir', 'Teemo', 'Tristana', 'Twitch', 'Varus', 'Vayne', 'Xayah', 'Zeri'], 'Support': ['Alistar', 'Anivia', 'Ashe', 'Bard', 'Braum', 'Fiddlesticks', 'Heimerdinger', 'Ivern', 'Janna', 'Karma', 'Kayle', 'Leona', 'Lulu', 'Lux', 'Morgana', 'Nami', 'Neeko', 'Orianna', 'Pyke', 'Rakan', 'Renata Glasc', 'Senna', 'Seraphine', 'Sona', 'Soraka', 'Syndra', 'Tahm Kench', 'Taliyah', 'Taric', 'Thresh', 'Yuumi', 'Zilean', 'Zoe', 'Zyra'], 'Fighter': ['Aatrox', 'Blitzcrank', 'Camille', 'Darius', 'Diana', 'Dr. Mundo', 'Ekko', 'Elise', 'Fiora', 'Fizz', 'Gangplank', 'Garen', 'Gnar', 'Gragas', 'Gwen', 'Hecarim', 'Illaoi', 'Irelia', 'Jarvan IV', 'Jax', 'Jayce', 'Kayle', 'Kayn', 'Kled', 'Lee Sin', 'Lillia', 'Malphite', 'Master Yi', 'Wukong', 'Mordekaiser', 'Nasus', 'Nautilus', 'Nocturne', 'Nunu & Willump', 'Olaf', 'Ornn', 'Pantheon', 'Poppy', 'Qiyana', 'Rammus', "Rek'Sai", 'Renekton', 'Rengar', 'Riven', 'Rumble', 'Ryze', 'Sejuani', 'Sett', 'Shyvana', 'Singed', 'Sion', 'Skarner', 'Swain', 'Taric', 'Thresh', 'Trundle', 'Tryndamere', 'Udyr', 'Urgot', 'Vi', 'Viego', 'Volibear', 'Warwick', 'Xin Zhao', 'Yasuo', 'Yone', 'Yorick', 'Zac']}
# dict_keys(['Tank', 'Mage', 'Assassin', 'Marksman', 'Support', 'Fighter'])

# %%
def kda(details):
    data = {}
    team_blue = []
    team_red = []
    team_blue_summoner_ids = []
    team_red_summoner_ids = []

    # Loop through participants to separate them into blue and red teams
    for i in range(10):
        if details['info']['participants'][i]['teamId'] == 100:
            team_blue.append(i)
        else:
            team_red.append(i)

    if details['info']['participants'][team_blue[0]]['win'] == True:
        data['blue_win'] = 1
    else:
        data['blue_win'] = 0

    # Initialize variables for blue and red teams
    blue_k = 0
    blue_a = 0
    blue_d = 0
    red_k = 0
    red_a = 0
    red_d = 0

    # Calculate stats for blue team
    for i in team_blue:
        blue_k += details['info']['participants'][i]['kills']
        blue_d += details['info']['participants'][i]['deaths']
        blue_a += details['info']['participants'][i]['assists']
        team_blue_summoner_ids.append(details['info']['participants'][i]['summonerId'])

    # Calculate stats for red team
    for i in team_red:
        red_k += details['info']['participants'][i]['kills']
        red_d += details['info']['participants'][i]['deaths']
        red_a += details['info']['participants'][i]['assists']
        team_red_summoner_ids.append(details['info']['participants'][i]['summonerId'])

    # Calculate KDA (Kills, Deaths, Assists) for each team
    blue_kda = (blue_k + blue_a) / max(1, blue_d)  # Avoid division by zero
    red_kda = (red_k + red_a) / max(1, red_d)  # Avoid division by zero

    # Store data into the dictionary
    data['blue_kills'] = blue_k
    data['blue_deaths'] = blue_d
    data['blue_assists'] = blue_a
    data['blue_kda'] = blue_kda

    data['red_kills'] = red_k
    data['red_deaths'] = red_d
    data['red_assists'] = red_a
    data['red_kda'] = red_kda

    return data, team_blue, team_red, team_blue_summoner_ids, team_red_summoner_ids

# %%
def champ(details, data, team_blue, team_red):
    for key in champion_classes:
        data[f'blue_{key}'] = 0
        data[f'red_{key}'] = 0

    for i in team_blue:
        champion_name = details['info']['participants'][i]['championName']
        for key in champion_classes:
            if champion_name in champion_classes[key]:
                champ_lvl = details['info']['participants'][i]['champLevel']
                champ_exp = details['info']['participants'][i]['champExperience']
                data[f'blue_{key}'] += champ_lvl * champ_exp

    for i in team_red:
        champion_name = details['info']['participants'][i]['championName']
        for key in champion_classes:
            if champion_name in champion_classes[key]:
                champ_lvl = details['info']['participants'][i]['champLevel']
                champ_exp = details['info']['participants'][i]['champExperience']
                data[f'red_{key}'] += champ_lvl * champ_exp

    return data

# %%
def rank_score(data, team_blue_summoner_ids, team_red_summoner_ids):
    avg_rank_score_red = 0
    avg_rank_score_blue = 0
    r = 0
    b = 0

    for summoner_id in team_blue_summoner_ids:
        rank_score = riot_api.get_combined_rank_score(summoner_id)
        if rank_score:
            avg_rank_score_blue += rank_score
            b += 1
        # print(f"Player Blue: Summoner ID: {summoner_id}, Combined Rank Score: {rank_score}")

    for summoner_id in team_red_summoner_ids:
        rank_score = riot_api.get_combined_rank_score(summoner_id)
        if rank_score:
            avg_rank_score_red += rank_score
            r += 1
        # print(f"Player Red: Summoner ID: {summoner_id}, Combined Rank Score: {rank_score}")

    avg_rank_score_red = avg_rank_score_red / r
    avg_rank_score_blue = avg_rank_score_blue / b
    data['rank_score_red'] = avg_rank_score_red
    data['rank_score_blue'] = avg_rank_score_blue
    return data

# %%
import requests
import time
import pandas as pd

class RiotApi(object):
    def __init__(self, api_key: str, region="americas"):
        self.RIOT_API_KEY = api_key
        self.HEADER = {'X-Riot-Token': self.RIOT_API_KEY}
        self.REGION = region
        self.BASE_URL = ".api.riotgames.com/"

    def match_details(self, match_id):
        self.REGION = "americas"
        url = f"https://{self.REGION}{self.BASE_URL}/lol/match/v5/matches/{match_id}"
        request = requests.get(url, headers=self.HEADER)
        if request.status_code == 200:
            return request.json()
        else:
            print(f"Error: Received status code {request.status_code} for match details request. Response: {request.text}")
            return {}
    
    def get_rank_and_tier(self, summoner_id: str) -> dict:
        """Get Rank and Tier by Summoner ID
        @param summoner_id: Summoner ID
        @return: json object of rank and tier data
        """
        self.REGION = "NA1"
        url = f"https://{self.REGION}{self.BASE_URL}lol/league/v4/entries/by-summoner/{summoner_id}"
        request = requests.get(url, headers=self.HEADER)
        if request.status_code == 200:
            return request.json()
        else:
            print(f"Error: Received status code {request.status_code} for rank request. Response: {request.text}")
            return {}

    def get_rank_score(self, tier, rank):
        tier_scores = {
            'IRON': 1,
            'BRONZE': 2,
            'SILVER': 3,
            'GOLD': 4,
            'PLATINUM': 5,
            'EMERALD': 6,
            'DIAMOND': 7,
            'MASTER': 8,
            'GRANDMASTER': 9,
            'CHALLENGER': 10
        }

        rank_scores = {
            'IV': 1,
            'III': 2,
            'II': 3,
            'I': 4
        }
        
        if tier in ['MASTER', 'GRANDMASTER', 'CHALLENGER']:
            return tier_scores[tier] * 4  # Using a high score for these ranks
        else:
            return (tier_scores[tier] * 4) + rank_scores[rank]
    
    def get_combined_rank_score(self, summoner_id):
        rank_data = self.get_rank_and_tier(summoner_id)
        for entry in rank_data:
            if entry['queueType'] == 'RANKED_SOLO_5x5':
                tier = entry['tier']
                rank = entry['rank']
                return self.get_rank_score(tier, rank)
        return None  # If no rank found

# Example usage
API_KEY = 'RGAPI-a20a58ce-8d55-4b21-9e4d-09766c9382be'  # Replace with your valid API key

# Initialize the Riot API class
riot_api = RiotApi(API_KEY)

# Get match details for the first match ID
for i in range(1159):
    match_id = match_ids[i]
    details = riot_api.match_details(match_id)
    print(len(details))
    data, team_blue, team_red, team_blue_summoner_ids, team_red_summoner_ids = kda(details)
    data = champ(details, data, team_blue, team_red)
    data = rank_score(data, team_blue_summoner_ids, team_red_summoner_ids)

    # appending multiple match data dictionaries
    matches_data.append(data)
    print(len(matches_data), "hi", i)
# Out:
# 2
# 1 hi 0
# 2
# 2 hi 1
# 2

# %%
print(matches_data)
print(len(matches_data))
# Out:
# [{'blue_win': 0, 'blue_kills': 17, 'blue_deaths': 37, 'blue_assists': 21, 'blue_kda': 1.027027027027027, 'red_kills': 37, 'red_deaths': 17, 'red_assists': 54, 'red_kda': 5.352941176470588, 'blue_Tank': 143897, 'red_Tank': 0, 'blue_Mage': 248223, 'red_Mage': 141414, 'blue_Assassin': 117672, 'red_Assassin': 762463, 'blue_Marksman': 265521, 'red_Marksman': 147706, 'blue_Support': 105444, 'red_Support': 141414, 'blue_Fighter': 143897, 'red_Fighter': 516431, 'rank_score_red': 40.0, 'rank_score_blue': 38.4}, {'blue_win': 0, 'blue_kills': 35, 'blue_deaths': 43, 'blue_assists': 56, 'blue_kda': 2.116279069767442, 'red_kills': 43, 'red_deaths': 35, 'red_assists': 70, 'red_kda': 3.2285714285714286, 'blue_Tank': 589970, 'red_Tank': 235648, 'blue_Mage': 433890, 'red_Mage': 367758, 'blue_Assassin': 257536, 'red_Assassin': 367758, 'blue_Marksman': 0, 'red_Marksman': 578842, 'blue_Support': 433890, 'red_Support': 241792, 'blue_Fighter': 589970, 'red_Fighter': 235648, 'rank_score_red': 39.2, 'rank_score_blue': 38.4}, {'blue_win': 1, 'blue_kills': 2, 'blue_deaths': 0, 'blue_assists': 3, 'blue_kda': 5.0, 'red_kills': 0, 'red_deaths': 2, 'red_assists': 0, 'red_kda': 0.0, 'blue_Tank': 19, 'red_Tank': 0, 'blue_Mage': 87, 'red_Mage': 24, 'blue_Assassin': 28, 'red_Assassin': 86, 'blue_Marksman': 87, 'red_Marksman': 0, 'blue_Support': 0, 'red_Support': 0, 'blue_Fighter': 19, 'red_Fighter': 24, 'rank_score_red': 37.6, 'rank_score_blue': 38.4}, {'blue_win': 1, 'blue_kills': 18, 'blue_deaths': 5, 'blue_assists': 14, 'blue_kda': 6.4, 'red_kills': 5, 'red_deaths': 18, 'red_assists': 5, 'red_kda': 0.5555555555555556, 'blue_Tank': 0, 'red_Tank': 106632, 'blue_Mage': 87065, 'red_Mage': 140157, 'blue_Assassin': 68590, 'red_Assassin': 0, 'blue_Marksman': 53982, 'red_Marksman': 139496, 'blue_Support': 0, 'red_Support': 33552, 'blue_Fighter': 198305, 'red_Fighter': 53118, 'rank_score_red': 39.2, 'rank_score_blue': 39.2}, {'blue_win': 0, 'blue_kills': 25, 'blue_deaths': 29, 'blue_assists': 27, 'blue_kda': 1.793103448275862, 'red_kills': 29, 'red_deaths': 25, 'red_assists': 58, 'red_kda': 3.48, 'blue_Tank': 346764, 'red_Tank': 134979, 'blue_Mage': 175098, 'red_Mage': 262336, 'blue_Assassin': 0, 'red_Assassin': 241168, 'blue_Marksman': 251040, 'red_Marksman': 213510, 'blue_Support': 87340, 'red_Support': 262336, 'blue_Fighter': 259424, 'red_Fighter': 376147, 'rank_score_red': 38.4, 'rank_score_blue': 37.6}, {'blue_win': 0, 'blue_kills': 13, 'blue_deaths': 34, 'blue_assists': 25, 'blue_kda': 1.1176470588235294, 'red_kills': 34, 'red_deaths': 13, 'red_assists': 39, 'red_kda': 5.615384615384615, 'blue_Tank': 86174, 'red_Tank': 166368, 'blue_Mage': 165951, 'red_Mage': 0, 'blue_Assassin': 0, 'red_Assassin': 116232, 'blue_Marksman': 0, 'red_Marksman': 360639, 'blue_Support': 53235, 'red_Support': 0, 'blue_Fighter': 86174, 'red_Fighter': 166368, 'rank_score_red': 38.4, 'rank_score_blue': 40.0}, {'blue_win': 0, 'blue_kills': 16, 'blue_deaths': 38, 'blue_assists': 22, 'blue_kda': 1.0, 'red_kills': 38, 'red_deaths': 16, 'red_assists': 46, 'red_kda': 5.25, 'blue_Tank': 0, 'red_Tank': 0, 'blue_Mage': 398221, 'red_Mage': 0, 'blue_Assassin': 140738, 'red_Assassin': 286569, 'blue_Marksman': 288873, 'red_Marksman': 199890, 'blue_Support': 162680, 'red_Support': 172984, 'blue_Fighter': 231862, 'red_Fighter': 286569, 'rank_score_red': 39.2, 'rank_score_blue': 39.2}, {'blue_win': 0, 'blue_kills': 39, 'blue_deaths': 42, 'blue_assists': 77, 'blue_kda': 2.761904761904762, 'red_kills': 42, 'red_deaths': 39, 'red_assists': 83, 'red_kda': 3.2051282051282053, 'blue_Tank': 413726, 'red_Tank': 162302, 'blue_Mage': 237536, 'red_Mage': 655698, 'blue_Assassin': 289867, 'red_Assassin': 662950, 'blue_Marksman': 289867, 'red_Marksman': 603976, 'blue_Support': 0, 'red_Support': 508226, 'blue_Fighter': 176190, 'red_Fighter': 368748, 'rank_score_red': 39.2, 'rank_score_blue': 38.4}, {'blue_win': 0, 'blue_kills': 27, 'blue_deaths': 52, 'blue_assists': 21, 'blue_kda': 0.9230769230769231, 'red_kills': 52, ...
# 172

# %%
import pickle
with open('list_of_matches_for_testing_details.pkl', 'wb') as file:
    pickle.dump(matches_data, file)

# %%
with open('chumma.pkl', 'rb') as file:
    matches_data_1 = pickle.load(file)
print(matches_data_1)
print(len(matches_data_1))
# Out:
# [{'blue_win': 0, 'blue_kills': 44, 'blue_deaths': 46, 'blue_assists': 106, 'blue_kda': 3.260869565217391, 'red_kills': 46, 'red_deaths': 44, 'red_assists': 93, 'red_kda': 3.159090909090909, 'blue_Tank': 0, 'red_Tank': 0, 'blue_Mage': 904812, 'red_Mage': 597034, 'blue_Assassin': 986040, 'red_Assassin': 0, 'blue_Marksman': 0, 'red_Marksman': 341262, 'blue_Support': 549546, 'red_Support': 344970, 'blue_Fighter': 630774, 'red_Fighter': 252064, 'rank_score_red': 32.2, 'rank_score_blue': 30.333333333333332}, {'blue_win': 1, 'blue_kills': 38, 'blue_deaths': 21, 'blue_assists': 69, 'blue_kda': 5.095238095238095, 'red_kills': 21, 'red_deaths': 38, 'red_assists': 31, 'red_kda': 1.368421052631579, 'blue_Tank': 0, 'red_Tank': 0, 'blue_Mage': 420960, 'red_Mage': 384603, 'blue_Assassin': 257536, 'red_Assassin': 556023, 'blue_Marksman': 256672, 'red_Marksman': 207555, 'blue_Support': 420960, 'red_Support': 105348, 'blue_Fighter': 257536, 'red_Fighter': 180348, 'rank_score_red': 36.0, 'rank_score_blue': 37.0}, {'blue_win': 0, 'blue_kills': 17, 'blue_deaths': 33, 'blue_assists': 28, 'blue_kda': 1.3636363636363635, 'red_kills': 33, 'red_deaths': 17, 'red_assists': 56, 'red_kda': 5.235294117647059, 'blue_Tank': 162988, 'red_Tank': 0, 'blue_Mage': 523264, 'red_Mage': 254832, 'blue_Assassin': 0, 'red_Assassin': 280602, 'blue_Marksman': 341577, 'red_Marksman': 552288, 'blue_Support': 103992, 'red_Support': 163716, 'blue_Fighter': 444083, 'red_Fighter': 418548, 'rank_score_red': 36.0, 'rank_score_blue': 36.8}, {'blue_win': 0, 'blue_kills': 14, 'blue_deaths': 33, 'blue_assists': 21, 'blue_kda': 1.0606060606060606, 'red_kills': 33, 'red_deaths': 14, 'red_assists': 47, 'red_kda': 5.714285714285714, 'blue_Tank': 0, 'red_Tank': 215040, 'blue_Mage': 92059, 'red_Mage': 0, 'blue_Assassin': 303543, 'red_Assassin': 0, 'blue_Marksman': 114024, 'red_Marksman': 0, 'blue_Support': 92059, 'red_Support': 118560, 'blue_Fighter': 0, 'red_Fighter': 333600, 'rank_score_red': 35.5, 'rank_score_blue': 36.0}, {'blue_win': 1, 'blue_kills': 47, 'blue_deaths': 21, 'blue_assists': 55, 'blue_kda': 4.857142857142857, 'red_kills': 21, 'red_deaths': 47, 'red_assists': 29, 'red_kda': 1.0638297872340425, 'blue_Tank': 0, 'red_Tank': 104688, 'blue_Mage': 196185, 'red_Mage': 165928, 'blue_Assassin': 640559, 'red_Assassin': 0, 'blue_Marksman': 444374, 'red_Marksman': 173304, 'blue_Support': 117228, 'red_Support': 232528, 'blue_Fighter': 0, 'red_Fighter': 104688, 'rank_score_red': 35.0, 'rank_score_blue': 34.0}, {'blue_win': 0, 'blue_kills': 16, 'blue_deaths': 30, 'blue_assists': 32, 'blue_kda': 1.6, 'red_kills': 30, 'red_deaths': 16, 'red_assists': 61, 'red_kda': 5.6875, 'blue_Tank': 187945, 'red_Tank': 374790, 'blue_Mage': 166628, 'red_Mage': 325236, 'blue_Assassin': 172172, 'red_Assassin': 210360, 'blue_Marksman': 103980, 'red_Marksman': 162918, 'blue_Support': 166628, 'red_Support': 114876, 'blue_Fighter': 360117, 'red_Fighter': 374790, 'rank_score_red': 37.0, 'rank_score_blue': 37.0}, {'blue_win': 0, 'blue_kills': 31, 'blue_deaths': 37, 'blue_assists': 43, 'blue_kda': 2.0, 'red_kills': 37, 'red_deaths': 31, 'red_assists': 43, 'red_kda': 2.5806451612903225, 'blue_Tank': 0, 'red_Tank': 0, 'blue_Mage': 336978, 'red_Mage': 134225, 'blue_Assassin': 370442, 'red_Assassin': 831013, 'blue_Marksman': 359527, 'red_Marksman': 243408, 'blue_Support': 119268, 'red_Support': 134225, 'blue_Fighter': 370442, 'red_Fighter': 587605, 'rank_score_red': 37.0, 'rank_score_blue': 36.6}, {'blue_win': 0, 'blue_kills': 8, 'blue_deaths': 21, 'blue_assists': 12, 'blue_kda': 0.9523809523809523, 'red_kills': 21, 'red_deaths': 8, 'red_assists': 30, 'red_kda': 6.375, 'blue_Tank': 167818, 'red_Tank': 0, 'blue_Mage': 277566, 'red_Mage': 312546, 'blue_Assassin': 172914, 'red_Assassin': 220140, 'blue_Marksman': 104652, 'red_Marksman': 176190, 'blue_Support': 63980, 'red_Support': 63010, 'blue_Fighter': 167818, 'red_Fighter': 469676, 'rank_score_red': 35.0, 'rank_score_blue': 39.2}, {'blue_win': 0, 'blue_kills': 24, ' ...
# 361

# %%
with open('list_of_matches_details.pkl', 'rb') as file:
    matches_data_1 = pickle.load(file)
print(matches_data_1)
print(len(matches_data_1))
# Out:
# [{'blue_win': 0, 'blue_kills': 44, 'blue_deaths': 46, 'blue_assists': 106, 'blue_kda': 3.260869565217391, 'red_kills': 46, 'red_deaths': 44, 'red_assists': 93, 'red_kda': 3.159090909090909, 'blue_Tank': 0, 'red_Tank': 0, 'blue_Mage': 904812, 'red_Mage': 597034, 'blue_Assassin': 986040, 'red_Assassin': 0, 'blue_Marksman': 0, 'red_Marksman': 341262, 'blue_Support': 549546, 'red_Support': 344970, 'blue_Fighter': 630774, 'red_Fighter': 252064, 'rank_score_red': 32.2, 'rank_score_blue': 30.333333333333332}, {'blue_win': 1, 'blue_kills': 38, 'blue_deaths': 21, 'blue_assists': 69, 'blue_kda': 5.095238095238095, 'red_kills': 21, 'red_deaths': 38, 'red_assists': 31, 'red_kda': 1.368421052631579, 'blue_Tank': 0, 'red_Tank': 0, 'blue_Mage': 420960, 'red_Mage': 384603, 'blue_Assassin': 257536, 'red_Assassin': 556023, 'blue_Marksman': 256672, 'red_Marksman': 207555, 'blue_Support': 420960, 'red_Support': 105348, 'blue_Fighter': 257536, 'red_Fighter': 180348, 'rank_score_red': 36.0, 'rank_score_blue': 37.0}, {'blue_win': 0, 'blue_kills': 17, 'blue_deaths': 33, 'blue_assists': 28, 'blue_kda': 1.3636363636363635, 'red_kills': 33, 'red_deaths': 17, 'red_assists': 56, 'red_kda': 5.235294117647059, 'blue_Tank': 162988, 'red_Tank': 0, 'blue_Mage': 523264, 'red_Mage': 254832, 'blue_Assassin': 0, 'red_Assassin': 280602, 'blue_Marksman': 341577, 'red_Marksman': 552288, 'blue_Support': 103992, 'red_Support': 163716, 'blue_Fighter': 444083, 'red_Fighter': 418548, 'rank_score_red': 36.0, 'rank_score_blue': 36.8}, {'blue_win': 0, 'blue_kills': 14, 'blue_deaths': 33, 'blue_assists': 21, 'blue_kda': 1.0606060606060606, 'red_kills': 33, 'red_deaths': 14, 'red_assists': 47, 'red_kda': 5.714285714285714, 'blue_Tank': 0, 'red_Tank': 215040, 'blue_Mage': 92059, 'red_Mage': 0, 'blue_Assassin': 303543, 'red_Assassin': 0, 'blue_Marksman': 114024, 'red_Marksman': 0, 'blue_Support': 92059, 'red_Support': 118560, 'blue_Fighter': 0, 'red_Fighter': 333600, 'rank_score_red': 35.5, 'rank_score_blue': 36.0}, {'blue_win': 1, 'blue_kills': 47, 'blue_deaths': 21, 'blue_assists': 55, 'blue_kda': 4.857142857142857, 'red_kills': 21, 'red_deaths': 47, 'red_assists': 29, 'red_kda': 1.0638297872340425, 'blue_Tank': 0, 'red_Tank': 104688, 'blue_Mage': 196185, 'red_Mage': 165928, 'blue_Assassin': 640559, 'red_Assassin': 0, 'blue_Marksman': 444374, 'red_Marksman': 173304, 'blue_Support': 117228, 'red_Support': 232528, 'blue_Fighter': 0, 'red_Fighter': 104688, 'rank_score_red': 35.0, 'rank_score_blue': 34.0}, {'blue_win': 0, 'blue_kills': 16, 'blue_deaths': 30, 'blue_assists': 32, 'blue_kda': 1.6, 'red_kills': 30, 'red_deaths': 16, 'red_assists': 61, 'red_kda': 5.6875, 'blue_Tank': 187945, 'red_Tank': 374790, 'blue_Mage': 166628, 'red_Mage': 325236, 'blue_Assassin': 172172, 'red_Assassin': 210360, 'blue_Marksman': 103980, 'red_Marksman': 162918, 'blue_Support': 166628, 'red_Support': 114876, 'blue_Fighter': 360117, 'red_Fighter': 374790, 'rank_score_red': 37.0, 'rank_score_blue': 37.0}, {'blue_win': 0, 'blue_kills': 31, 'blue_deaths': 37, 'blue_assists': 43, 'blue_kda': 2.0, 'red_kills': 37, 'red_deaths': 31, 'red_assists': 43, 'red_kda': 2.5806451612903225, 'blue_Tank': 0, 'red_Tank': 0, 'blue_Mage': 336978, 'red_Mage': 134225, 'blue_Assassin': 370442, 'red_Assassin': 831013, 'blue_Marksman': 359527, 'red_Marksman': 243408, 'blue_Support': 119268, 'red_Support': 134225, 'blue_Fighter': 370442, 'red_Fighter': 587605, 'rank_score_red': 37.0, 'rank_score_blue': 36.6}, {'blue_win': 0, 'blue_kills': 8, 'blue_deaths': 21, 'blue_assists': 12, 'blue_kda': 0.9523809523809523, 'red_kills': 21, 'red_deaths': 8, 'red_assists': 30, 'red_kda': 6.375, 'blue_Tank': 167818, 'red_Tank': 0, 'blue_Mage': 277566, 'red_Mage': 312546, 'blue_Assassin': 172914, 'red_Assassin': 220140, 'blue_Marksman': 104652, 'red_Marksman': 176190, 'blue_Support': 63980, 'red_Support': 63010, 'blue_Fighter': 167818, 'red_Fighter': 469676, 'rank_score_red': 35.0, 'rank_score_blue': 39.2}, {'blue_win': 0, 'blue_kills': 24, ' ...
# 361

# %%
df = pd.DataFrame(matches_data)
# Save the DataFrame to a CSV file
df.to_csv('matches.csv', index=False)
